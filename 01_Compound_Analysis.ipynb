# %% [markdown]
# # Main compound analisis after compound dicovery step
#
# Requirements:
# - Exported compounds database in excel format
# - Exported Chemspider results database in excel format

# %%
import config
import cutils as utils

import pandas as pd
import chemspi_web_db as chemsearch
from chemspi_web_db import ChemspiWebDB
from chemspi_local_db import ChemspiLocalDB

# %%
# Input
folder = "tests/"
compounds_database_file = folder + "01_Compound_Analysis_input.xlsx"

web_api_key = "9GS3pzBwGsrdu0agqqP7buFcYwaaX2GH"
chemspider_local_db_file = folder + "cs_localdb.xlsx"

export_file = folder + "01_Compound_Analysis_result"

# %%
# init resources and databases
compounds_table = pd.read_excel(compounds_database_file)
chempider_local_db = ChemspiLocalDB(chemspider_local_db_file)
chempider_web_db = chemsearch.ChemspiWebDB(web_api_key)

# remove not needed columns
#compounds_table.drop(columns=['Checked'], inplace=True)

print("Sucess reading databases")
display(compounds_table)
# Out:
# Sucess reading databases
#    Checked                                           Name      Formula  \
# 0    False                                N-Bromaziridine   C2 H4 Br N
# 1    False                              THREONIC ACID, L-     C4 H8 O5
# 2    False  3,3,3-Trifluoro-N,N-dimethyl-1-propen-2-amine   C5 H8 F3 N
# 3    False                     2-(Vinylsulfanyl)thiophene     C6 H6 S2
# 4    False                                          I-BCP  C3 H6 Br Cl
# 5    False                       3,4-Difluorobenzoic acid  C7 H4 F2 O2
# 6    False                                        2206207  C7 H13 N O3
# 7    False                                    Indantrione     C9 H4 O3
# 8    False    Amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid  C5 H8 N2 O4
#
#   Annotation Source: Predicted Compositions Annotation Source: mzCloud Search  \
# 0                                No results                        No results
# 1                                Full match                        No results
# 2                                No results                        No results
# 3                                No results                        No results
# 4                                No results                      Invalid mass
# 5                                No results                        No results
# 6                                Full match                        No results
# 7                                Full match                        No results
# 8                                Full match                        No results
#
#   Annotation Source: Metabolika Search Annotation Source: ChemSpider Search  \
# 0                           No results                           Full match
# 1                           No results                           Full match
# 2                           No results                           Full match
# 3                           No results                           Full match
# 4                           No results                           Full match
# 5                           No results                           Full match
# 6                        Partial match                           Full match
# 7                           No results                           Full match
# 8                           No results                           Full match
#
#    FISh Coverage  Molecular Weight  RT [min]  ...  Group CV [%]: PT068  \
# 0            NaN         120.95231     0.351  ...            22.764124
# 1            NaN         136.03665     0.795  ...            24.967380
# 2            NaN         139.06154     3.654  ...             7.602523
# 3            NaN         141.99168     0.363  ...            61.191008
# 4            NaN         155.93389     0.342  ...            18.914425
# 5            NaN         158.01752     0.473  ...            42.249447
# 6            NaN         159.08980     4.527  ...           120.679216
# 7            NaN         160.01637     0.389  ...            40.183532
# 8            NaN         160.04778     0.349  ...           152.180458
#
#    Group CV [%]: PT082  Group CV [%]: PT089  Group CV [%]: PT110  \
# 0            26.550253            26.907520            14.373753
# 1            32.591837           107.985445            40.825420
# 2            60.524509             6.353632            98.754121
# 3            16.577958           135.470264           125.324460
# 4            41.815562            24.137139            52.409670
# 5            15.751291             4.600336             8.684451
# 6            98.940721           116.477596           128.887182
# 7            39.072120           137.679602           148.133662
# 8           131.229299           139.178731           144.192391
#
#   Group CV [%]: TM005  Group CV [%]: TM029  Group CV [%]: TM046  \
# 0           40.025127            13.782258            27.781494
# 1           37.440131            41.610274            66.097361
# 2          121.368966             9.555112            26.774001
# 3          115.738593            38.586905            46.974952
# 4           38.373321             9.631249            17.698679
# 5           28.175883            22.621428            29.654403
# 6          134.133145            36.042816             8.979055
# 7          122.094275            49.210189            32.150203
# 8          134.018005            30.358318            26.286085
#
#   Group CV [%]: TM054  Group CV [%]: TM071  Group CV [%]: TM083
# 0           41.803866            37.779677            62.103913
# 1            5.270171            17.023686           143.657107
# 2           60.789428            11.340633           136.599746
# 3           62.074057           102.437660           123.043024
# 4           26.800065            15.551652            18.881270
# 5           12.471525            38.087485            34.347617
# 6           83.289484           133.384005           151.512784
# 7           62.972833            54.539925           160.790658
# 8          117.088318           144.636569           159.097537
#
# [9 rows x 172 columns]

# %% [markdown]
# # Step 1: Removing duplicated entries
# - Sort by Name
# - Sort by area
# - Sort by retention time
# - Select from duplicated names: one with highest area then retention time

# %%
compounds_table = utils.remove_duplicated_entries(compounds_table)
print("Done")
compounds_table.to_excel(export_file + "_step1.xlsx")
display(compounds_table)
# Out:
# Done
#    Checked                                           Name      Formula  \
# 0    False                                n-bromaziridine   C2 H4 Br N
# 1    False                              threonic acid, l-     C4 H8 O5
# 2    False  3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine   C5 H8 F3 N
# 3    False                     2-(vinylsulfanyl)thiophene     C6 H6 S2
# 4    False                                          i-bcp  C3 H6 Br Cl
# 5    False                       3,4-difluorobenzoic acid  C7 H4 F2 O2
# 6    False                                        2206207  C7 H13 N O3
# 7    False                                    indantrione     C9 H4 O3
# 8    False    amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid  C5 H8 N2 O4
#
#   Annotation Source: Predicted Compositions Annotation Source: mzCloud Search  \
# 0                                No results                        No results
# 1                                Full match                        No results
# 2                                No results                        No results
# 3                                No results                        No results
# 4                                No results                      Invalid mass
# 5                                No results                        No results
# 6                                Full match                        No results
# 7                                Full match                        No results
# 8                                Full match                        No results
#
#   Annotation Source: Metabolika Search Annotation Source: ChemSpider Search  \
# 0                           No results                           Full match
# 1                           No results                           Full match
# 2                           No results                           Full match
# 3                           No results                           Full match
# 4                           No results                           Full match
# 5                           No results                           Full match
# 6                        Partial match                           Full match
# 7                           No results                           Full match
# 8                           No results                           Full match
#
#    FISh Coverage  Molecular Weight  RT [min]  ...  Group CV [%]: PT068  \
# 0            NaN         120.95231     0.351  ...            22.764124
# 1            NaN         136.03665     0.795  ...            24.967380
# 2            NaN         139.06154     3.654  ...             7.602523
# 3            NaN         141.99168     0.363  ...            61.191008
# 4            NaN         155.93389     0.342  ...            18.914425
# 5            NaN         158.01752     0.473  ...            42.249447
# 6            NaN         159.08980     4.527  ...           120.679216
# 7            NaN         160.01637     0.389  ...            40.183532
# 8            NaN         160.04778     0.349  ...           152.180458
#
#    Group CV [%]: PT082  Group CV [%]: PT089  Group CV [%]: PT110  \
# 0            26.550253            26.907520            14.373753
# 1            32.591837           107.985445            40.825420
# 2            60.524509             6.353632            98.754121
# 3            16.577958           135.470264           125.324460
# 4            41.815562            24.137139            52.409670
# 5            15.751291             4.600336             8.684451
# 6            98.940721           116.477596           128.887182
# 7            39.072120           137.679602           148.133662
# 8           131.229299           139.178731           144.192391
#
#   Group CV [%]: TM005  Group CV [%]: TM029  Group CV [%]: TM046  \
# 0           40.025127            13.782258            27.781494
# 1           37.440131            41.610274            66.097361
# 2          121.368966             9.555112            26.774001
# 3          115.738593            38.586905            46.974952
# 4           38.373321             9.631249            17.698679
# 5           28.175883            22.621428            29.654403
# 6          134.133145            36.042816             8.979055
# 7          122.094275            49.210189            32.150203
# 8          134.018005            30.358318            26.286085
#
#   Group CV [%]: TM054  Group CV [%]: TM071  Group CV [%]: TM083
# 0           41.803866            37.779677            62.103913
# 1            5.270171            17.023686           143.657107
# 2           60.789428            11.340633           136.599746
# 3           62.074057           102.437660           123.043024
# 4           26.800065            15.551652            18.881270
# 5           12.471525            38.087485            34.347617
# 6           83.289484           133.384005           151.512784
# 7           62.972833            54.539925           160.790658
# 8          117.088318           144.636569           159.097537
#
# [9 rows x 172 columns]

# %% [markdown]
# # Step 2: Find CSId from chemspi databases
# - Try local first
# - Try online otherwise

# %%
#compounds_table = pd.read_excel(export_file + "_step1.xlsx")

csid_values = []
iupac_values = []

num_rows = compounds_table.shape[0]
row_count = 0
for row_index, row_data in compounds_table.iterrows() :    
    row_count += 1
    compound_name = str(row_data.Name).lower()
    compound_mass = row_data[config.CA_MOL_WEIGHT_COL]
    print('({:d}/{:d}) searching compound info '.format(row_count, num_rows) + compound_name)
    
    ids = chempider_local_db.find_compound_ids_by_name_mass(compound_name, compound_mass)    
    if len(ids) == 0:
        print("Not found in local db, searching online")
        ids = chempider_web_db.find_compound_ids_by_name_mass(compound_name, compound_mass)
    
    csid_values.append(utils.CSID_list_to_string(ids))
    
compounds_table.insert(0, 'CSID', csid_values)
#display(compounds_table)
compounds_table.to_excel(export_file + "_step2.xlsx")
print("Done")
# Out:
# (1/9) searching compound info n-bromaziridine
# (2/9) searching compound info threonic acid, l-
# (3/9) searching compound info 3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine
# (4/9) searching compound info 2-(vinylsulfanyl)thiophene
# (5/9) searching compound info i-bcp
# (6/9) searching compound info 3,4-difluorobenzoic acid
# (7/9) searching compound info 2206207
# (8/9) searching compound info indantrione
# (9/9) searching compound info amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid
# Done

# %% [markdown]
# # Step 3: Find IUPAC Name

# %%
#compounds_table = pd.read_excel(export_file + "_step2.xlsx")
iupac_values = []

num_rows = compounds_table.shape[0]
row_count = 0
for row_index, row_data in compounds_table.iterrows() :    
    row_count += 1
    compound_name = str(row_data.Name).lower()
    compound_csids = row_data['CSID']
    print('({:d}/{:d}) searching IUPAC Name '.format(row_count, num_rows) + compound_name)
    iupac_value = ""
    if not pd.isna(compound_csids):
        for csid in utils.parse_generated_CSID(compound_csids):
            compound = chempider_web_db.find_compound_by_id(csid)    
            iupac_value = iupac_value + compound.iupac_name + ";"
        
        
    iupac_values.append(iupac_value)
    
compounds_table.insert(0, 'IUPAC Name', iupac_values)
#display(compounds_table)
compounds_table.to_excel(export_file + "_step3.xlsx")
print("Done.")
# Out:
# (1/9) searching IUPAC Name n-bromaziridine
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.466501.html ...  Done. Took 0.193251371383667 seconds
# (2/9) searching IUPAC Name threonic acid, l-
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.388628.html ...  Done. Took 0.16863632202148438 seconds
# (3/9) searching IUPAC Name 3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.510190.html ...  Done. Took 0.1709434986114502 seconds
# (4/9) searching IUPAC Name 2-(vinylsulfanyl)thiophene
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.479757.html ...  Done. Took 0.16910076141357422 seconds
# (5/9) searching IUPAC Name i-bcp
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.7715.html ...  Done. Took 0.1590712070465088 seconds
# (6/9) searching IUPAC Name 3,4-difluorobenzoic acid
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.89588.html ...  Done. Took 0.17833256721496582 seconds
# (7/9) searching IUPAC Name 2206207
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.168243.html ...  Done. Took 0.16884613037109375 seconds
# (8/9) searching IUPAC Name indantrione
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.63492.html ...  Done. Took 0.15254950523376465 seconds
# (9/9) searching IUPAC Name amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid
# Waiting for http request:  http://www.chemspider.com/Chemical-Structure.133122.html ...  Done. Took 0.15009474754333496 seconds
# Done.

# %% [markdown]
# # Step 4: Find External references from chemspi web search

# %%
compounds_table = pd.read_excel(export_file + "_step3.xlsx")
external_databases = ['Human Metabolome Database', 'KEGG', 'LipidMAPS']
external_db_info = dict()
for db in external_databases:
    external_db_info[db] = []
        
num_rows = compounds_table.shape[0]
row_count = 0
for row_index, row_data in compounds_table.iterrows() :
    # search for external references from known databases
    row_count += 1
    print('({:d}/{:d}) Finding external references for '.format(row_count, num_rows) + row_data.Name)
    external_databases_result = {}
    for db in external_databases:
        external_databases_result[db] = []
    
    for csid in utils.parse_generated_CSID(row_data.CSID):
        print("CSID: ", csid)
        external_refs = chemsearch.http_find_compound_external_sources_ids(csid, external_databases)
        display(external_refs)
        
        #if len(warnings) > 0 :
        #    display(warnings)
        
        for db, values in external_refs.items():
            external_databases_result[db].extend(values)
    
    for db, values in external_databases_result.items():
        str_result = ""
        for v in values :
            str_result += str(v) + ";"
        external_db_info[db].append(str_result)
        
insert_pos = 1
for db_name, value in external_db_info.items():
    compounds_table.insert(insert_pos, db_name, value)
    insert_pos += 1

#display(compounds_table)
compounds_table.to_excel(export_file + "_step4.xlsx")
print("Done!")
# Out:
# (1/9) Finding external references for n-bromaziridine
# CSID:  466501
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=466501&type=ds ...  Done. Took 0.05903482437133789 seconds
# {'Human Metabolome Database': [], 'KEGG': [], 'LipidMAPS': []}
# (2/9) Finding external references for threonic acid, l-
# CSID:  388628
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=388628&type=ds ...  Done. Took 0.017989158630371094 seconds
# {'Human Metabolome Database': [],
#  'KEGG': ['C01620'],
#  'LipidMAPS': ['LMFA01050097']}
# (3/9) Finding external references for 3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine
# CSID:  510190
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=510190&type=ds ...  Done. Took 0.008004426956176758 seconds
# {'Human Metabolome Database': [], 'KEGG': [], 'LipidMAPS': []}
# (4/9) Finding external references for 2-(vinylsulfanyl)thiophene
# CSID:  479757
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=479757&type=ds ...  Done. Took 0.011008739471435547 seconds
# {'Human Metabolome Database': [], 'KEGG': [], 'LipidMAPS': []}
# (5/9) Finding external references for i-bcp
# CSID:  7715
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=7715&type=ds ...  Done. Took 0.018998146057128906 seconds
# {'Human Metabolome Database': [], 'KEGG': [], 'LipidMAPS': []}
# (6/9) Finding external references for 3,4-difluorobenzoic acid
# CSID:  89588
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=89588&type=ds ...  Done. Took 0.09296894073486328 seconds
# {'Human Metabolome Database': [], 'KEGG': [], 'LipidMAPS': []}
# (7/9) Finding external references for 2206207
# CSID:  168243
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=168243&type=ds ...  Done. Took 0.014001607894897461 seconds
# {'Human Metabolome Database': ['HMDB00339', 'HMDB0000339'],
#  'KEGG': [],
#  'LipidMAPS': []}
# (8/9) Finding external references for indantrione
# CSID:  63492
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=63492&type=ds ...  Done. Took 0.014007806777954102 seconds
# {'Human Metabolome Database': [], 'KEGG': [], 'LipidMAPS': []}
# (9/9) Finding external references for amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid
# CSID:  133122
# Waiting for http request:  http://www.chemspider.com/ibcontent.ashx?csid=133122&type=ds ...  Done. Took 0.0030145645141601562 seconds
# {'Human Metabolome Database': ['HMDB30412', 'HMDB0030412'],
#  'KEGG': [],
#  'LipidMAPS': []}
# Done!

# %% [markdown]
# # Step 5: Search not found HMDB metabolites

# %%
compounds_table = pd.read_excel(export_file + "_step4.xlsx")
#display(compounds_table)
import hmdb_web_db as hmdb_web
num_rows = compounds_table.shape[0]
row_count = 0
for row_index, row_data in compounds_table.iterrows() :
    hmdb_info = row_data['Human Metabolome Database']
    print('({:d}/{:d})Missing HMDB id: '.format(row_count, num_rows), row_data.Name)
    row_count+=1
    if pd.isna(hmdb_info) or len(hmdb_info) == 0:
        if not row_data.Name.isnumeric():
            print("Searching by Name")
            metabolites = hmdb_web.search_metabolites_by_name_mass(row_data.Name, row_data[config.CA_MOL_WEIGHT_COL])
            compounds_table.loc[row_index, "Human Metabolome Database"] = utils.CSID_list_to_string(metabolites)
        else:
            print("Searching by IUPAC Name")
            iupac_names = row_data["IUPAC Name"]
            names_list = ""
            for iupac in iupac_names.split(';'):
                metabolites = hmdb_web.search_metabolites_by_name_mass(iupac, row_data[config.CA_MOL_WEIGHT_COL])
                if len(metabolites) > 0:     
                    names_list += utils.CSID_list_to_string(metabolites)
            compounds_table.loc[row_index, "Human Metabolome Database"] = names_list

compounds_table.to_excel(export_file + "_step5.xlsx")
print("Done!")
# Out:
# (0/9)Missing HMDB id:  n-bromaziridine
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="n-bromaziridine"&searcher=metabolites ...  Done. Took 0.1361227035522461 seconds
# (1/9)Missing HMDB id:  threonic acid, l-
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="threonic acid, l-"&searcher=metabolites ...  Done. Took 0.09292149543762207 seconds
# Waiting for http request:  https://hmdb.ca/metabolites/HMDB0000943 ...  Done. Took 0.09810471534729004 seconds
# (2/9)Missing HMDB id:  3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine"&searcher=metabolites ...  Done. Took 0.07605671882629395 seconds
# (3/9)Missing HMDB id:  2-(vinylsulfanyl)thiophene
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="2-(vinylsulfanyl)thiophene"&searcher=metabolites ...  Done. Took 0.0741424560546875 seconds
# (4/9)Missing HMDB id:  i-bcp
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="i-bcp"&searcher=metabolites ...  Done. Took 0.08104419708251953 seconds
# (5/9)Missing HMDB id:  3,4-difluorobenzoic acid
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="3,4-difluorobenzoic acid"&searcher=metabolites ...  Done. Took 0.08841967582702637 seconds
# (6/9)Missing HMDB id:  2206207
# (7/9)Missing HMDB id:  indantrione
# Searching by Name
# Waiting for http request:  https://hmdb.ca/unearth/q?utf8=%E2%9C%93&query="indantrione"&searcher=metabolites ...  Done. Took 0.05719327926635742 seconds
# (8/9)Missing HMDB id:  amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid
# Done!

# %% [markdown]
# # Step 6: Search HMDB info

# %%
import hmdb_web_db as hmdb_web

#compounds_table = pd.read_excel(export_file + "_step5.xlsx")

info_titles = ["Super Class", "Class", "Sub Class"]
compounds_columns = ["Name", "IUPAC Name", "Human Metabolome Database"]

columns = compounds_columns + info_titles
output_data = {title : [] for title in columns}

#####
num_rows = compounds_table.shape[0]
row_count = 0
for row_index, row_data in compounds_table.iterrows() :
    hmdb_ids = row_data['Human Metabolome Database']
    print('({:d}/{:d})Searching HMDB info: '.format(row_count, num_rows), hmdb_ids)
    row_count+=1
    
    #### search hmdb info
    hmdb_info = None
    if not pd.isna(hmdb_ids) and len(str(hmdb_ids)) > 0:
        for hmdb_id in hmdb_ids.split(';'):
            hmdb_info = hmdb_web.search_metabolite_info_by_id(hmdb_id, info_titles)
            print(hmdb_info)
            break
    
    #### set hmdb data
    if hmdb_info != None:        
        print(hmdb_info)
        for column_name, value in hmdb_info.items():        
            output_data[column_name].append(value)
    else:
        for column_name in info_titles:
            output_data[column_name].append("")
        
    #### set compounds data
    for column_name in compounds_columns:
        output_data[column_name].append(row_data[column_name])
        
            
result = pd.DataFrame.from_dict(output_data)
result.to_excel(export_file + "_step6.xlsx")
display(result)
   

#compounds_table.to_excel(export_file + "_step6.xlsx")
print("Done!")
# Out:
# (0/9)Searching HMDB info:
# (1/9)Searching HMDB info:  HMDB0000943
# Waiting for http request:  https://hmdb.ca/metabolites/HMDB0000943 ...  Done. Took 0.0019991397857666016 seconds
# {'Super Class': 'Organic oxygen compounds', 'Class': 'Organooxygen compounds', 'Sub Class': 'Carbohydrates and carbohydrate conjugates'}
# {'Super Class': 'Organic oxygen compounds', 'Class': 'Organooxygen compounds', 'Sub Class': 'Carbohydrates and carbohydrate conjugates'}
# (2/9)Searching HMDB info:
# (3/9)Searching HMDB info:
# (4/9)Searching HMDB info:
# (5/9)Searching HMDB info:
# (6/9)Searching HMDB info:  HMDB00339;HMDB0000339;
# Waiting for http request:  https://hmdb.ca/metabolites/HMDB00339 ...  Done. Took 0.0921623706817627 seconds
# {'Super Class': 'Organic acids and derivatives', 'Class': 'Carboxylic acids and derivatives', 'Sub Class': 'Amino acids, peptides, and analogues'}
# {'Super Class': 'Organic acids and derivatives', 'Class': 'Carboxylic acids and derivatives', 'Sub Class': 'Amino acids, peptides, and analogues'}
# (7/9)Searching HMDB info:
# (8/9)Searching HMDB info:  HMDB30412;HMDB0030412;
# Waiting for http request:  https://hmdb.ca/metabolites/HMDB30412 ...  Done. Took 0.07338523864746094 seconds
# {'Super Class': 'Organic acids and derivatives', 'Class': 'Carboxylic acids and derivatives', 'Sub Class': 'Amino acids, peptides, and analogues'}
# {'Super Class': 'Organic acids and derivatives', 'Class': 'Carboxylic acids and derivatives', 'Sub Class': 'Amino acids, peptides, and analogues'}
#                                             Name  \
# 0                                n-bromaziridine
# 1                              threonic acid, l-
# 2  3,3,3-trifluoro-n,n-dimethyl-1-propen-2-amine
# 3                     2-(vinylsulfanyl)thiophene
# 4                                          i-bcp
# 5                       3,4-difluorobenzoic acid
# 6                                        2206207
# 7                                    indantrione
# 8    amino(3-oxo-1,2-oxazolidin-5-yl)acetic acid
#
#                                        IUPAC Name Human Metabolome Database  \
# 0                            Aziridine, 1-bromo-;
# 1          (2R,3S)-2,3,4-Trihydroxybutanoic acid;               HMDB0000943
# 2  3,3,3-Trifluoro-N,N-dimethyl-1-propen-2-amine;
# 3                    Thiophene, 2-(ethenylthio)-;
# 4                     Propane, 1-bromo-3-chloro-;
# 5                    Benzoic acid, 3,4-difluoro-;
# 6                    N-(2-Methylbutanoyl)glycine;    HMDB00339;HMDB0000339;
# 7                         1H-Indene-1,2,3-trione;
# 8     Amino(3-oxo-1,2-oxazolidin-5-yl)aceticacid;    HMDB30412;HMDB0030412;
#
#                      Super Class                             Class  \
# 0
# 1       Organic oxygen compounds            Organooxygen compounds
# 2
# 3
# 4
# 5
# 6  Organic acids and derivatives  Carboxylic acids and derivatives
# 7
# 8  Organic acids and derivatives  Carboxylic acids and derivatives
#
#                                    Sub Class
# 0
# 1  Carbohydrates and carbohydrate conjugates
# 2
# 3
# 4
# 5
# 6       Amino acids, peptides, and analogues
# 7
# 8       Amino acids, peptides, and analogues
# Done!
